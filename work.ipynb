# %%
import pandas as pd

# %%
df = pd.read_csv("juyo-d1-j.csv",  encoding="Shift_JIS", skiprows=54, nrows=235-56+1, usecols=[0,1,2], parse_dates=["DATE"])
df
# Out:
#           DATE   TIME  当日実績(５分間隔値)(万kW)
# 0   2023-10-07   0:00              2390
# 1   2023-10-07   0:05              2358
# 2   2023-10-07   0:10              2355
# 3   2023-10-07   0:15              2345
# 4   2023-10-07   0:20              2315
# ..         ...    ...               ...
# 175 2023-10-07  14:35              2763
# 176 2023-10-07  14:40              2750
# 177 2023-10-07  14:45              2750
# 178 2023-10-07  14:50              2738
# 179 2023-10-07  14:55              2747
#
# [180 rows x 3 columns]

# %%
import japanize_matplotlib
df.plot()
# Out:
# <Axes: >
